# %%
from model.types import MarketDemandSupply
from model.run import load_config, run

from model.mechanism.amm_k import amm_k_mechanism

initialstate = { # variable values borrowed from liquidity-olympus/simulation.ipynb
            'supply':30000000,
            "liq_stables": 21000000,
            "reserves_stables":200000000,
            "reserves_volatile":17000000,
            "price":9,

            "market_demand_supply": MarketDemandSupply(total_supply = 50,
                                                   total_demand = 50),
                                                   
            # treasury policy
            'target_liq_ratio_reached':False,
            'reserves_in':0,

            # RBS related
            'ma_target':9,
            # market transaction variables
            'ask_change_ohm':0,
            'bid_change_ohm':0,
            "net_flow": None
            }
# initialize parameters that are decided by other parameters
initialstate['amm_k'] = amm_k_mechanism(initialstate)
initialstate['price_history']=[initialstate['price']]

params = {"demand_factor": [10],
         "supply_factor": [10],
         "reward_rate":[0.000198], # flat reward rate; (1 + r) ^ 365 ~ 7.5%
         "max_liq_ratio":[0.14375],  # LiquidityUSD : reservesUSD ratio --> 1:1 = 0.5
         "target_ma":[30], # number of days
         }

nrun = 5
nstep = 10
exp = load_config(nrun, params, initialstate, nstep)
run(exp)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# cadCAD Version: 0.4.28
# Execution Mode: local_proc
# Simulation Dimensions:
# Entire Simulation: (Models, Unique Timesteps, Params, Total Runs, Sub-States) = (1, 10, 5, 5, 14)
#      Simulation 0: (Timesteps, Params, Runs, Sub-States) = (10, 5, 5, 14)
# Execution Method: local_simulations
# Execution Mode: parallelized
# Total execution time: 0.55s
#            supply  liq_stables  reserves_stables  reserves_volatile  price  \
# 0    3.000000e+07     21000000         200000000           17000000      9
# 1    3.000000e+07     21000000         200000000           17000000      9
# 2    3.000000e+07     21000000         200000000           17000000      9
# 3    3.000594e+07     21000000         200000000           17000000      9
# 4    3.000594e+07     21000000         200000000           17000000      9
# ..            ...          ...               ...                ...    ...
# 300  3.125050e+07     21000000         200000000           17000000      9
# 301  3.125669e+07     21000000         200000000           17000000      9
# 302  3.125669e+07     21000000         200000000           17000000      9
# 303  3.125669e+07     21000000         200000000           17000000      9
# 304  3.125669e+07     21000000         200000000           17000000      9
#
#                                   market_demand_supply  \
# 0    MarketDemandSupply(total_supply=50, total_dema...
# 1    MarketDemandSupply(total_supply=50, total_dema...
# 2    MarketDemandSupply(total_supply=50, total_dema...
# 3    MarketDemandSupply(total_supply=50, total_dema...
# 4    MarketDemandSupply(total_supply=50, total_dema...
# ..                                                 ...
# 300  MarketDemandSupply(total_supply=50, total_dema...
# 301  MarketDemandSupply(total_supply=50, total_dema...
# 302  MarketDemandSupply(total_supply=50, total_dema...
# 303  MarketDemandSupply(total_supply=50, total_dema...
# 304  MarketDemandSupply(total_supply=50, total_dema...
#
#      target_liq_ratio_reached  reserves_in  ma_target  ask_change_ohm  \
# 0                       False          0.0        9.0               0
# 1                       False          0.0        9.0               0
# 2                       False          0.0        9.0               0
# 3                       False          0.0        9.0               0
# 4                       False          0.0        9.0               0
# ..                        ...          ...        ...             ...
# 300                     False          0.0        9.0               0
# 301                     False          0.0        9.0               0
# 302                     False          0.0        9.0               0
# 303                     False          0.0        9.0               0
# 304                     False          0.0        9.0               0
#
#      bid_change_ohm net_flow         amm_k                      price_history  \
# 0                 0     None  4.900000e+13                                [9]
# 1                 0     None  4.900000e+13                                [9]
# 2                 0     None  4.900000e+13                             [9, 9]
# 3                 0     None  4.900000e+13                             [9, 9]
# 4                 0     None  4.900000e+13                             [9, 9]
# ..              ...      ...           ...                                ...
# 300               0     None  4.900000e+13  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# 301               0     None  4.900000e+13  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# 302               0     None  4.900000e+13  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# 303               0     None  4.900000e+13  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# 304               0     None  4.900000e+13  [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
#
#      simulation  subset  run  substep  timestep  treasury_stables
# 0             0       0    1        0         0               NaN
# 1             0       0    1        1         1       221000000.0
# 2             0       0    1        2         1       221000000.0
# 3             0       0    1        3         1       221000000.0
# 4             0       0    1        4         1       221000000.0
# ..          ...     ...  ...      ...       ...               ...
# 300           0       0    5        2        10       221000000.0
# 301           0       0    5        3        10       221000000.0
# 302           0       0    5        4        10       221000000.0
# 303           0       0    5        5        10       221000000.0
# 304           0       0    5        6        10       221000000.0
#
# [305 rows x 20 columns]

# %%
a= [1]
b = a+[2]

# %%
b
# Out:
# [1, 2]
