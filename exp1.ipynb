# %%
from model.types import MarketDemandSupply
from model.run import load_config, run

from model.mechanism.amm_k import amm_k_mechanism
from model.mechanism.treasury import liq_backing_mechanism,treasury_stables_mechanism
from model.mechanism.rbs_price import lower_target_wall_mechanism,upper_target_wall_mechanism
initialstate = { # variable values borrowed from liquidity-olympus/simulation.ipynb
            'supply':30000000,
            "liq_stables": 21000000,
            "reserves_stables":200000000,
            "reserves_volatile":17000000,
            "price":9,

            "market_demand_supply": MarketDemandSupply(total_supply = 50,
                                                   total_demand = 50),
                                                   
            # treasury policy
            'target_liq_ratio_reached':False,
            'reserves_in':0,

            # RBS related
            'ma_target':9,
            # market transaction variables
            'ask_change_ohm':0,
            'bid_change_ohm':0,
            "net_flow": None
            }
# initialize parameters that are decided by other parameters
initialstate['amm_k'] = amm_k_mechanism(initialstate)
initialstate['price_history']=[initialstate['price']]
initialstate['lb_target'] = initialstate['ma_target']
initialstate['price_target']=initialstate['ma_target']

params = {"demand_factor": [10],
         "supply_factor": [10],
         "initial_reserves_volatile":[17000000], # setting it as constant since in this simulation we don't use it at all.
         "reward_rate":[0.000198], # flat reward rate; (1 + r) ^ 365 ~ 7.5%
         "max_liq_ratio":[0.14375],  # LiquidityUSD : reservesUSD ratio --> 1:1 = 0.5
         "target_ma":[30], # number of days
         "lower_wall":[0.15],
         "upper_wall":[0.15],
         }

initialstate['treasury_stables'] = treasury_stables_mechanism(initialstate['liq_stables'],initialstate['reserves_stables'])
initialstate['liq_backing'] = liq_backing_mechanism(initialstate['treasury_stables'],params['initial_reserves_volatile'][0])
initialstate['lower_target_wall'] = lower_target_wall_mechanism(initialstate['price_target'], params['lower_wall'][0])
initialstate['upper_target_wall'] = upper_target_wall_mechanism(initialstate['price_target'], params['upper_wall'][0])
nrun = 5
nstep = 10
exp = load_config(nrun, params, initialstate, nstep)
run(exp)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# cadCAD Version: 0.4.28
# Execution Mode: local_proc
# Simulation Dimensions:
# Entire Simulation: (Models, Unique Timesteps, Params, Total Runs, Sub-States) = (1, 10, 8, 5, 20)
#      Simulation 0: (Timesteps, Params, Runs, Sub-States) = (10, 8, 5, 20)
# Execution Method: local_simulations
# Execution Mode: parallelized
# Total execution time: 0.86s
#            supply  liq_stables  reserves_stables  reserves_volatile  price  \
# 0    3.000000e+07     21000000         200000000           17000000      9
# 1    3.000000e+07     21000000         200000000           17000000      9
# 2    3.000000e+07     21000000         200000000           17000000      9
# 3    3.000000e+07     21000000         200000000           17000000      9
# 4    3.000000e+07     21000000         200000000           17000000      9
# ..            ...          ...               ...                ...    ...
# 450  3.125050e+07     21000000         200000000           17000000      9
# 451  3.125050e+07     21000000         200000000           17000000      9
# 452  3.125669e+07     21000000         200000000           17000000      9
# 453  3.125669e+07     21000000         200000000           17000000      9
# 454  3.125669e+07     21000000         200000000           17000000      9
#
#                                   market_demand_supply  \
# 0    MarketDemandSupply(total_supply=50, total_dema...
# 1    MarketDemandSupply(total_supply=50, total_dema...
# 2    MarketDemandSupply(total_supply=50, total_dema...
# 3    MarketDemandSupply(total_supply=50, total_dema...
# 4    MarketDemandSupply(total_supply=50, total_dema...
# ..                                                 ...
# 450  MarketDemandSupply(total_supply=50, total_dema...
# 451  MarketDemandSupply(total_supply=50, total_dema...
# 452  MarketDemandSupply(total_supply=50, total_dema...
# 453  MarketDemandSupply(total_supply=50, total_dema...
# 454  MarketDemandSupply(total_supply=50, total_dema...
#
#      target_liq_ratio_reached  reserves_in  ma_target  ask_change_ohm  ...  \
# 0                       False          0.0        9.0               0  ...
# 1                       False          0.0        9.0               0  ...
# 2                       False          0.0        9.0               0  ...
# 3                       False          0.0        9.0               0  ...
# 4                       False          0.0        9.0               0  ...
# ..                        ...          ...        ...             ...  ...
# 450                     False          0.0        9.3               0  ...
# 451                     False          0.0        9.3               0  ...
# 452                     False          0.0        9.3               0  ...
# 453                     False          0.0        9.3               0  ...
# 454                     False          0.0        9.3               0  ...
#
#      price_target treasury_stables  liq_backing lower_target_wall  \
# 0             9.0        221000000    238000000             7.650
# 1             9.0        221000000    238000000             7.650
# 2             9.0        221000000    238000000             7.650
# 3             9.0        221000000    238000000             7.650
# 4             9.0        221000000    238000000             7.650
# ..            ...              ...          ...               ...
# 450           9.3        221000000    238000000             7.905
# 451           9.3        221000000    238000000             7.905
# 452           9.3        221000000    238000000             7.905
# 453           9.3        221000000    238000000             7.905
# 454           9.3        221000000    238000000             7.905
#
#      upper_target_wall  simulation  subset  run  substep  timestep
# 0               10.350           0       0    1        0         0
# 1               10.350           0       0    1        1         1
# 2               10.350           0       0    1        2         1
# 3               10.350           0       0    1        3         1
# 4               10.350           0       0    1        4         1
# ..                 ...         ...     ...  ...      ...       ...
# 450             10.695           0       0    5        5        10
# 451             10.695           0       0    5        6        10
# 452             10.695           0       0    5        7        10
# 453             10.695           0       0    5        8        10
# 454             10.695           0       0    5        9        10
#
# [455 rows x 25 columns]
